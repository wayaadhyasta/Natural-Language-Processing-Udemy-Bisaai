# %% [markdown]
# <a href="https://colab.research.google.com/github/wayaadhyasta/Natural-Language-Processing-Udemy-Bisaai/blob/main/NLP(UDEMY).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Text Processing**

# %% [markdown]
# ## Text PreProcessing

# %% [markdown]
# ### NLP

# %% [markdown]
# NLP adalah Natural Language *Processing*

# %%
perkalian = 4*5
print(perkalian)
# Out:
# 20

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.6.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.11.15
# aiosignal                             1.3.2
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.6
# ale-py                                0.11.0
# altair                                5.5.0
# annotated-types                       0.7.0
# anyio                                 4.9.0
# argon2-cffi                           23.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.2
# arviz                                 0.21.0
# astropy                               7.0.1
# astropy-iers-data                     0.2025.4.28.0.37.27
# astunparse                            1.6.3
# atpublic                              5.1
# attrs                                 25.3.0
# audioread                             3.0.1
# autograd                              1.7.0
# babel                                 2.17.0
# backcall                              0.2.0
# backports.tarfile                     1.2.0
# beautifulsoup4                        4.13.4
# betterproto                           2.0.0b6
# bigframes                             2.1.0
# bigquery-magics                       0.9.0
# bleach                                6.2.0
# blinker                               1.9.0
# blis                                  1.3.0
# blosc2                                3.3.2
# bokeh                                 3.7.2
# Bottleneck                            1.4.2
# bqplot                                0.12.44
# branca                                0.8.1
# build                                 1.2.2.post1
# CacheControl                          0.14.3
# cachetools                            5.5.2
# catalogue                             2.0.10
# certifi                               2025.4.26
# cffi                                  1.17.1
# chardet                               5.2.0
# charset-normalizer                    3.4.1
# chex                                  0.1.89
# clarabel                              0.10.0
# click                                 8.1.8
# cloudpathlib                          0.21.0
# cloudpickle                           3.1.1
# cmake                                 3.31.6
# cmdstanpy                             1.2.5
# colorcet                              3.1.0
# colorlover                            0.3.0
# colour                                0.1.5
# community                             1.0.0b1
# confection                            0.1.5
# cons                                  0.4.6
# contourpy                             1.3.2
# cramjam                               2.10.0
# cryptography                          43.0.3
# cuda-python                           12.6.2.post1
# cudf-cu12                             25.2.1
# cudf-polars-cu12                      25.2.2
# cufflinks                             0.17.3
# cuml-cu12                             25.2.1
# cupy-cuda12x                          13.3.0
# cuvs-cu12                             25.2.1
# cvxopt                                1.3.2
# cvxpy                                 1.6.5
# cycler                                0.12.1
# cyipopt                               1.5.0
# cymem                                 2.0.11
# Cython                                3.0.12
# dask                                  2024.12.1
# dask-cuda                             25.2.0
# dask-cudf-cu12                        25.2.2
# dask-expr                             1.1.21
# dataproc-spark-connect                0.7.2
# datascience                           0.17.6
# db-dtypes                             1.4.2
# dbus-python                           1.2.18
# debugpy                               1.8.0
# decorator                             4.4.2
# defusedxml                            0.7.1
# Deprecated                            1.2.18
# diffusers                             0.33.1
# distributed                           2024.12.1
# distributed-ucxx-cu12                 0.42.0
# distro                                1.9.0
# dlib                                  19.24.6
# dm-tree                               0.1.9
# docker-pycreds                        0.4.0
# docstring_parser                      0.16
# docutils                              0.21.2
# dopamine_rl                           4.1.2
# duckdb                                1.2.2
# earthengine-api                       1.5.13
# easydict                              1.13
# editdistance                          0.8.1
# eerepr                                0.1.1
# einops                                0.8.1
# en_core_web_sm                        3.8.0
# entrypoints                           0.4
# et_xmlfile                            2.0.0
# etils                                 1.12.2
# etuples                               0.3.9
# Farama-Notifications                  0.0.4
# fastai                                2.7.19
# fastcore                              1.7.29
# fastdownload                          0.0.7
# fastjsonschema                        2.21.1
# fastprogress                          1.0.3
# fastrlock                             0.8.3
# filelock                              3.18.0
# firebase-admin                        6.8.0
# Flask                                 3.1.0
# flatbuffers                           25.2.10
# flax                                  0.10.6
# folium                                0.19.5
# fonttools                             4.57.0
# frozendict                            2.4.6
# frozenlist                            1.6.0
# fsspec                                2025.3.2
# future                                1.0.0
# gast                                  0.6.0
# gcsfs                                 2025.3.2
# GDAL                                  3.6.4
# gdown                                 5.2.0
# geemap                                0.35.3
# geocoder                              1.38.1
# geographiclib                         2.0
# geopandas                             1.0.1
# geopy                                 2.4.1
# gin-config                            0.5.0
# gitdb                                 4.0.12
# GitPython                             3.1.44
# glob2                                 0.7
# google                                2.0.3
# google-ai-generativelanguage          0.6.15
# google-api-core                       2.24.2
# google-api-python-client              2.169.0
# google-auth                           2.38.0
# google-auth-httplib2                  0.2.0
# google-auth-oauthlib                  1.2.2
# google-cloud-aiplatform               1.91.0
# google-cloud-bigquery                 3.31.0
# google-cloud-bigquery-connection      1.18.2
# google-cloud-bigquery-storage         2.31.0
# google-cloud-bigtable                 2.30.1
# google-cloud-core                     2.4.3
# google-cloud-dataproc                 5.18.1
# google-cloud-datastore                2.21.0
# google-cloud-firestore                2.20.2
# google-cloud-functions                1.20.3
# google-cloud-iam                      2.19.0
# google-cloud-language                 2.17.1
# google-cloud-pubsub                   2.25.0
# google-cloud-resource-manager         1.14.2
# google-cloud-spanner                  3.54.0
# google-cloud-storage                  2.19.0
# google-cloud-translate                3.20.2
# google-colab                          1.0.0
# google-crc32c                         1.7.1
# google-genai                          1.13.0
# google-generativeai                   0.8.5
# google-pasta                          0.2.0
# google-resumable-media                2.7.2
# googleapis-common-protos              1.70.0
# googledrivedownloader                 1.1.0
# graphviz                              0.20.3
# greenlet                              3.2.1
# grpc-google-iam-v1                    0.14.2
# grpc-interceptor                      0.15.4
# grpcio                                1.71.0
# grpcio-status                         1.71.0
# grpclib                               0.4.7
# gspread                               6.2.0
# gspread-dataframe                     4.0.0
# gym                                   0.25.2
# gym-notices                           0.0.8
# gymnasium                             1.1.1
# h11                                   0.16.0
# h2                                    4.2.0
# h5netcdf                              1.6.1
# h5py                                  3.13.0
# hdbscan                               0.8.40
# highspy                               1.10.0
# holidays                              0.71
# holoviews                             1.20.2
# hpack                                 4.1.0
# html5lib                              1.1
# httpcore                              1.0.9
# httpimport                            1.4.1
# httplib2                              0.22.0
# httpx                                 0.28.1
# huggingface-hub                       0.30.2
# humanize                              4.12.3
# hyperframe                            6.1.0
# hyperopt                              0.2.7
# ibis-framework                        9.5.0
# idna                                  3.10
# imageio                               2.37.0
# imageio-ffmpeg                        0.6.0
# imagesize                             1.4.1
# imbalanced-learn                      0.13.0
# immutabledict                         4.2.1
# importlib_metadata                    8.7.0
# importlib_resources                   6.5.2
# imutils                               0.5.4
# inflect                               7.5.0
# iniconfig                             2.1.0
# intel-cmplr-lib-ur                    2025.1.1
# intel-openmp                          2025.1.1
# ipyevents                             2.0.2
# ipyfilechooser                        0.6.0
# ipykernel                             6.17.1
# ipyleaflet                            0.19.2
# ipyparallel                           8.8.0
# ipython                               7.34.0
# ipython-genutils                      0.2.0
# ipython-sql                           0.5.0
# ipytree                               0.2.2
# ipywidgets                            7.7.1
# itsdangerous                          2.2.0
# jaraco.classes                        3.4.0
# jaraco.context                        6.0.1
# jaraco.functools                      4.1.0
# jax                                   0.5.2
# jax-cuda12-pjrt                       0.5.1
# jax-cuda12-plugin                     0.5.1
# jaxlib                                0.5.1
# jeepney                               0.9.0
# jieba                                 0.42.1
# Jinja2                                3.1.6
# jiter                                 0.9.0
# joblib                                1.4.2
# jsonpatch                             1.33
# jsonpickle                            4.0.5
# jsonpointer                           3.0.0
# jsonschema                            4.23.0
# jsonschema-specifications             2025.4.1
# jupyter-client                        6.1.12
# jupyter-console                       6.1.0
# jupyter_core                          5.7.2
# jupyter_kernel_gateway                2.5.2
# jupyter-leaflet                       0.19.2
# jupyter-server                        1.16.0
# jupyterlab_pygments                   0.3.0
# jupyterlab_widgets                    3.0.14
# kaggle                                1.7.4.2
# kagglehub                             0.3.12
# keras                                 3.8.0
# keras-hub                             0.18.1
# keras-nlp                             0.18.1
# keyring                               25.6.0
# keyrings.google-artifactregistry-auth 1.1.2
# kiwisolver                            1.4.8
# langchain                             0.3.24
# langchain-core                        0.3.56
# langchain-text-splitters              0.3.8
# langcodes                             3.5.0
# langsmith                             0.3.39
# language_data                         1.3.0
# launchpadlib                          1.10.16
# lazr.restfulclient                    0.14.4
# lazr.uri                              1.0.6
# lazy_loader                           0.4
# libclang                              18.1.1
# libcudf-cu12                          25.2.1
# libcugraph-cu12                       25.2.0
# libcuml-cu12                          25.2.1
# libcuvs-cu12                          25.2.1
# libkvikio-cu12                        25.2.1
# libraft-cu12                          25.2.0
# librosa                               0.11.0
# libucx-cu12                           1.18.1
# libucxx-cu12                          0.42.0
# lightgbm                              4.5.0
# linkify-it-py                         2.0.3
# llvmlite                              0.43.0
# locket                                1.0.0
# logical-unification                   0.4.6
# lxml                                  5.4.0
# Mako                                  1.1.3
# marisa-trie                           1.2.1
# Markdown                              3.8
# markdown-it-py                        3.0.0
# MarkupSafe                            3.0.2
# matplotlib                            3.10.0
# matplotlib-inline                     0.1.7
# matplotlib-venn                       1.1.2
# mdit-py-plugins                       0.4.2
# mdurl                                 0.1.2
# miniKanren                            1.0.3
# missingno                             0.5.2
# mistune                               3.1.3
# mizani                                0.13.3
# mkl                                   2025.0.1
# ml-dtypes                             0.4.1
# mlxtend                               0.23.4
# more-itertools                        10.7.0
# moviepy                               1.0.3
# mpmath                                1.3.0
# msgpack                               1.1.0
# multidict                             6.4.3
# multipledispatch                      1.0.0
# multitasking                          0.0.11
# murmurhash                            1.0.12
# music21                               9.3.0
# namex                                 0.0.9
# narwhals                              1.37.1
# natsort                               8.4.0
# nbclassic                             1.3.0
# nbclient                              0.10.2
# nbconvert                             7.16.6
# nbformat                              5.10.4
# ndindex                               1.9.2
# nest-asyncio                          1.6.0
# networkx                              3.4.2
# nibabel                               5.3.2
# nltk                                  3.9.1
# notebook                              6.5.7
# notebook_shim                         0.2.4
# numba                                 0.60.0
# numba-cuda                            0.2.0
# numexpr                               2.10.2
# numpy                                 2.0.2
# nvidia-cublas-cu12                    12.5.3.2
# nvidia-cuda-cupti-cu12                12.5.82
# nvidia-cuda-nvcc-cu12                 12.5.82
# nvidia-cuda-nvrtc-cu12                12.5.82
# nvidia-cuda-runtime-cu12              12.5.82
# nvidia-cudnn-cu12                     9.3.0.75
# nvidia-cufft-cu12                     11.2.3.61
# nvidia-curand-cu12                    10.3.6.82
# nvidia-cusolver-cu12                  11.6.3.83
# nvidia-cusparse-cu12                  12.5.1.3
# nvidia-cusparselt-cu12                0.6.2
# nvidia-ml-py                          12.570.86
# nvidia-nccl-cu12                      2.21.5
# nvidia-nvcomp-cu12                    4.2.0.11
# nvidia-nvjitlink-cu12                 12.5.82
# nvidia-nvtx-cu12                      12.4.127
# nvtx                                  0.2.11
# nx-cugraph-cu12                       25.2.0
# oauth2client                          4.1.3
# oauthlib                              3.2.2
# openai                                1.76.2
# opencv-contrib-python                 4.11.0.86
# opencv-python                         4.11.0.86
# opencv-python-headless                4.11.0.86
# openpyxl                              3.1.5
# opentelemetry-api                     1.16.0
# opentelemetry-sdk                     1.16.0
# opentelemetry-semantic-conventions    0.37b0
# opt_einsum                            3.4.0
# optax                                 0.2.4
# optree                                0.15.0
# orbax-checkpoint                      0.11.13
# orjson                                3.10.18
# osqp                                  1.0.3
# packaging                             24.2
# pandas                                2.2.2
# pandas-datareader                     0.10.0
# pandas-gbq                            0.28.0
# pandas-stubs                          2.2.2.240909
# pandocfilters                         1.5.1
# panel                                 1.6.3
# param                                 2.2.0
# parso                                 0.8.4
# parsy                                 2.1
# partd                                 1.4.2
# pathlib                               1.0.1
# patsy                                 1.0.1
# peewee                                3.18.1
# peft                                  0.15.2
# pexpect                               4.9.0
# pickleshare                           0.7.5
# pillow                                11.2.1
# pip                                   24.1.2
# platformdirs                          4.3.7
# plotly                                5.24.1
# plotnine                              0.14.5
# pluggy                                1.5.0
# ply                                   3.11
# polars                                1.21.0
# pooch                                 1.8.2
# portpicker                            1.5.2
# preshed                               3.0.9
# prettytable                           3.16.0
# proglog                               0.1.11
# progressbar2                          4.5.0
# prometheus_client                     0.21.1
# promise                               2.3
# prompt_toolkit                        3.0.51
# propcache                             0.3.1
# prophet                               1.1.6
# proto-plus                            1.26.1
# protobuf                              5.29.4
# psutil                                5.9.5
# psycopg2                              2.9.10
# ptyprocess                            0.7.0
# py-cpuinfo                            9.0.0
# py4j                                  0.10.9.7
# pyarrow                               18.1.0
# pyasn1                                0.6.1
# pyasn1_modules                        0.4.2
# pycairo                               1.28.0
# pycocotools                           2.0.8
# pycparser                             2.22
# pydantic                              2.11.4
# pydantic_core                         2.33.2
# pydata-google-auth                    1.9.1
# pydot                                 3.0.4
# pydotplus                             2.0.2
# PyDrive                               1.3.1
# PyDrive2                              1.21.3
# pyerfa                                2.0.1.5
# pygame                                2.6.1
# pygit2                                1.18.0
# Pygments                              2.19.1
# PyGObject                             3.42.0
# PyJWT                                 2.10.1
# pylibcudf-cu12                        25.2.1
# pylibcugraph-cu12                     25.2.0
# pylibraft-cu12                        25.2.0
# pymc                                  5.22.0
# pymystem3                             0.2.0
# pynndescent                           0.5.13
# pynvjitlink-cu12                      0.5.2
# pynvml                                12.0.0
# pyogrio                               0.10.0
# pyomo                                 6.9.2
# PyOpenGL                              3.1.9
# pyOpenSSL                             24.2.1
# pyparsing                             3.2.3
# pyperclip                             1.9.0
# pyproj                                3.7.1
# pyproject_hooks                       1.2.0
# pyshp                                 2.3.1
# PySocks                               1.7.1
# pyspark                               3.5.1
# pytensor                              2.30.3
# pytest                                8.3.5
# python-apt                            0.0.0
# python-box                            7.3.2
# python-dateutil                       2.9.0.post0
# python-louvain                        0.16
# python-slugify                        8.0.4
# python-snappy                         0.7.3
# python-utils                          3.9.1
# pytz                                  2025.2
# pyviz_comms                           3.0.4
# PyYAML                                6.0.2
# pyzmq                                 24.0.1
# raft-dask-cu12                        25.2.0
# rapids-dask-dependency                25.2.0
# ratelim                               0.1.6
# referencing                           0.36.2
# regex                                 2024.11.6
# requests                              2.32.3
# requests-oauthlib                     2.0.0
# requests-toolbelt                     1.0.0
# requirements-parser                   0.9.0
# rich                                  13.9.4
# rmm-cu12                              25.2.0
# roman-numerals-py                     3.1.0
# rpds-py                               0.24.0
# rpy2                                  3.5.17
# rsa                                   4.9.1
# safetensors                           0.5.3
# scikit-image                          0.25.2
# scikit-learn                          1.6.1
# scipy                                 1.15.2
# scooby                                0.10.1
# scs                                   3.2.7.post2
# seaborn                               0.13.2
# SecretStorage                         3.3.3
# Send2Trash                            1.8.3
# sentence-transformers                 3.4.1
# sentencepiece                         0.2.0
# sentry-sdk                            2.27.0
# setproctitle                          1.3.6
# setuptools                            75.2.0
# shap                                  0.47.2
# shapely                               2.1.0
# shellingham                           1.5.4
# simple-parsing                        0.1.7
# simplejson                            3.20.1
# simsimd                               6.2.1
# six                                   1.17.0
# sklearn-compat                        0.1.3
# sklearn-pandas                        2.2.0
# slicer                                0.0.8
# smart-open                            7.1.0
# smmap                                 5.0.2
# sniffio                               1.3.1
# snowballstemmer                       2.2.0
# sortedcontainers                      2.4.0
# soundfile                             0.13.1
# soupsieve                             2.7
# soxr                                  0.5.0.post1
# spacy                                 3.8.5
# spacy-legacy                          3.0.12
# spacy-loggers                         1.0.5
# spanner-graph-notebook                1.1.6
# Sphinx                                8.2.3
# sphinxcontrib-applehelp               2.0.0
# sphinxcontrib-devhelp                 2.0.0
# sphinxcontrib-htmlhelp                2.1.0
# sphinxcontrib-jsmath                  1.0.1
# sphinxcontrib-qthelp                  2.0.0
# sphinxcontrib-serializinghtml         2.0.0
# SQLAlchemy                            2.0.40
# sqlglot                               25.20.2
# sqlparse                              0.5.3
# srsly                                 2.5.1
# stanio                                0.5.1
# statsmodels                           0.14.4
# stringzilla                           3.12.5
# sympy                                 1.13.1
# tables                                3.10.2
# tabulate                              0.9.0
# tbb                                   2022.1.0
# tblib                                 3.1.0
# tcmlib                                1.3.0
# tenacity                              9.1.2
# tensorboard                           2.18.0
# tensorboard-data-server               0.7.2
# tensorflow                            2.18.0
# tensorflow-datasets                   4.9.8
# tensorflow_decision_forests           1.11.0
# tensorflow-hub                        0.16.1
# tensorflow-io-gcs-filesystem          0.37.1
# tensorflow-metadata                   1.17.1
# tensorflow-probability                0.25.0
# tensorflow-text                       2.18.1
# tensorstore                           0.1.74
# termcolor                             3.1.0
# terminado                             0.18.1
# text-unidecode                        1.3
# textblob                              0.19.0
# tf_keras                              2.18.0
# tf-slim                               1.1.0
# thinc                                 8.3.6
# threadpoolctl                         3.6.0
# tifffile                              2025.3.30
# timm                                  1.0.15
# tinycss2                              1.4.0
# tokenizers                            0.21.1
# toml                                  0.10.2
# toolz                                 0.12.1
# torch                                 2.6.0+cu124
# torchaudio                            2.6.0+cu124
# torchsummary                          1.5.1
# torchvision                           0.21.0+cu124
# tornado                               6.4.2
# tqdm                                  4.67.1
# traitlets                             5.7.1
# traittypes                            0.2.1
# transformers                          4.51.3
# treelite                              4.4.1
# treescope                             0.1.9
# triton                                3.2.0
# tweepy                                4.15.0
# typeguard                             4.4.2
# typer                                 0.15.3
# types-pytz                            2025.2.0.20250326
# types-setuptools                      80.3.0.20250505
# typing_extensions                     4.13.2
# typing-inspection                     0.4.0
# tzdata                                2025.2
# tzlocal                               5.3.1
# uc-micro-py                           1.0.3
# ucx-py-cu12                           0.42.0
# ucxx-cu12                             0.42.0
# umap-learn                            0.5.7
# umf                                   0.10.0
# uritemplate                           4.1.1
# urllib3                               2.4.0
# vega-datasets                         0.9.0
# wadllib                               1.3.6
# wandb                                 0.19.10
# wasabi                                1.1.3
# wcwidth                               0.2.13
# weasel                                0.4.1
# webcolors                             24.11.1
# webencodings                          0.5.1
# websocket-client                      1.8.0
# websockets                            15.0.1
# Werkzeug                              3.1.3
# wheel                                 0.45.1
# widgetsnbextension                    3.6.10
# wordcloud                             1.9.4
# wrapt                                 1.17.2
# wurlitzer                             3.1.1
# xarray                                2025.3.1
# xarray-einstats                       0.8.0
# xgboost                               2.1.4
# xlrd                                  2.0.1
# xyzservices                           2025.4.0
# yarl                                  1.20.0
# ydf                                   0.11.0
# yellowbrick                           1.5
# yfinance                              0.2.57
# zict                                  3.0.0
# zipp                                  3.21.0
# zstandard                             0.23.0

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
import Sastrawi

# %%
# !python --version
# Out:
# Python 3.11.12

# %% [markdown]
# ## Lowecased

# %%
text = 'Adhyasta Adwaya Alkarim INFORMATIKA UTY'

# Menggunakan fungsi lower()
lowercase_text = text.lower()

# menampilkan hasil
print('Lowercased Text',lowercase_text)
# Out:
# Lowercased Text adhyasta adwaya alkarim informatika uty

# %% [markdown]
# hasil print dengan kata kapital tidak dibaca dengan komputer karna lowercase itu kata string itu semua sama dengan menggunakan kata huruf kecil

# %% [markdown]
# ## Punctuation

# %%
import string
teks = "Halo nama saya adalah Adhyasta Adwaya Alkarim INFORMATIKA UTY, angkatan 2023!!!"
teks_proses = teks.lower().translate(str.maketrans('','', string.punctuation))\
# lower() untuk menghubah huruf upercase jadi lowercase
# translate() untuk menghilangkan tanda baca yg tidak penting

# menampilkan hasil
print("Teks Setelah di Proses :", teks_proses)
# Out:
# Teks Setelah di Proses : halo nama saya adalah adhyasta adwaya alkarim informatika uty angkatan 2023

# %% [markdown]
# hasil print setelah teks di proses nama 'Halo' jadi 'halo', kata huruf depan 'A' jadi 'a', kata 'INFORMATIKA UTY' jadi 'informatika uty', tanda baca koma dan tanda seru hilang

# %% [markdown]
# ## Tokenization

# %%
import nltk

# %%
nltk.download('punkt_tab')
#untuk memanggil tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize
# word_tokenize itu untuk print satu kata

text = "Halo nama saya adalah Adhyasta Adwaya Alkarim INFORMATIKA UTY, angkatan 2023!!!"
word_tokens = word_tokenize(text)

# menampilkan hasil
print('Word Token', word_tokens)
# Out:
# Word Token ['Halo', 'nama', 'saya', 'adalah', 'Adhyasta', 'Adwaya', 'Alkarim', 'INFORMATIKA', 'UTY', ',', 'angkatan', '2023', '!', '!', '!']

# %%
from nltk.tokenize import sent_tokenize
# sent_tokenize itu untuk print satu kalimat yg memisahkan nya adalah tanda koma

text = "Halo nama saya adalah Adhyasta Adwaya Alkarim INFORMATIKA UTY, angkatan 2023!!!"
sentence_tokens = sent_tokenize(text)

# menampilkan hasil
print('Sentence Token', sentence_tokens)
# Out:
# Sentence Token ['Halo nama saya adalah Adhyasta Adwaya Alkarim INFORMATIKA UTY, angkatan 2023!!', '!']

# %%
import spacy
nlp = spacy.blank('id')

text = "hari ini saya belajar tentang Natural Language Processing."

doc = nlp(text)
# var dengan gabungan var nlp dan text

word_tokens = [token.text for token in doc]
# pada var ini adalah var untuk looping di antara var text dan doc dengan token.text

# menampilkan hasil
print('word tokens:', word_tokens)
# Out:
# word tokens: ['hari', 'ini', 'saya', 'belajar', 'tentang', 'Natural', 'Language', 'Processing', '.']

# %%
from textblob import TextBlob

text = 'Hari ini saya belajar tentang Natural Language Processing.'

blob = TextBlob(text)

# menampilkan hasil
word_tokens = blob.words
print('word tokens:', word_tokens)
# Out:
# word tokens: ['Hari', 'ini', 'saya', 'belajar', 'tentang', 'Natural', 'Language', 'Processing']

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

text = 'hari ini saya belajar Natural Language Processig.'

# menampilkan hasil
word_tokens = text.split()
print('word tokens:', word_tokens)
# Out:
# word tokens: ['hari', 'ini', 'saya', 'belajar', 'Natural', 'Language', 'Processig.']

# %% [markdown]
# ## Stopwords

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = 'This is an example sentence showing the removal of stopwords'

tokens = word_tokenize(text)

stop_words = set(stopwords.words('english'))

stopwords_removed = [word for word in tokens if word.lower() in stop_words]
filtered_removed = [word for word in tokens if word.lower() not in stop_words]

# menampilkan hasil
print('Original Tokens:', tokens)
print('Stopwords Removed:', stopwords_removed)
print('Filtered stopwords:', filtered_removed)
# Out:
# Original Tokens: ['This', 'is', 'an', 'example', 'sentence', 'showing', 'the', 'removal', 'of', 'stopwords']
# Stopwords Removed: ['This', 'is', 'an', 'the', 'of']
# Filtered stopwords: ['example', 'sentence', 'showing', 'removal', 'stopwords']

# %% [markdown]
# Stopwords NLTK Indonesia

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

txt = 'ini adalah contoh kalimat yang akan diproses untuk menghilangkan stopwords dalam bhs Indonesia'

tokens = word_tokenize(txt)

stop_words = set(stopwords.words('indonesian'))

stopwords_removed = [word for word in tokens if word.lower() in stop_words]
filtered_removed = [word for word in tokens if word.lower() not in stop_words]

# menampilkan hasil
print('Original Tokens:', tokens)
print('Stopword Removed:', stopwords_removed)
print('Filtered stopword:', filtered_removed)
# Out:
# Original Tokens: ['ini', 'adalah', 'contoh', 'kalimat', 'yang', 'akan', 'diproses', 'untuk', 'menghilangkan', 'stopwords', 'dalam', 'bhs', 'Indonesia']
# Stopword Removed: ['ini', 'adalah', 'yang', 'akan', 'untuk', 'dalam']
# Filtered stopword: ['contoh', 'kalimat', 'diproses', 'menghilangkan', 'stopwords', 'bhs', 'Indonesia']

# %%
stopwords.fileids()
# Out:
# ['albanian',
#  'arabic',
#  'azerbaijani',
#  'basque',
#  'belarusian',
#  'bengali',
#  'catalan',
#  'chinese',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hebrew',
#  'hinglish',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'tamil',
#  'turkish']

# %%
len(stopwords.words(['indonesian']))
# Out:
# 758

# %%
stopwords.words('indonesian')[:10]
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir']

# %%
stopwords.words('indonesian')[:20]
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara']

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

factory = StopWordRemoverFactory()
stopwords_removed = factory.create_stop_word_remover()

txt = 'Ini adalah contoh kalimat yang menunjukan panghapusan stopwords dengan Sastrawi.'

cleaned_txt = stopwords_removed.remove(txt)

# menampilkan hasil
print('Original Text:', txt)
print('clean Text after removed :', cleaned_txt)
# Out:
# Original Text: Ini adalah contoh kalimat yang menunjukan panghapusan stopwords dengan Sastrawi.
# clean Text after removed : Ini contoh kalimat menunjukan panghapusan stopwords Sastrawi.

# %% [markdown]
# ## Stemming

# %% [markdown]
# Stem dengan NLTK

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

txt = 'The quick brown foxes are jumping over the lazy dogs.'

tokens = word_tokenize(txt)

porter_stemmer = PorterStemmer()

stemmed_words = [porter_stemmer.stem(word) for word in tokens]

# menampilkan hasil
print('Original tokens:', tokens)
print('Stemmed tokens:', stemmed_words)
# Out:
# Original tokens: ['The', 'quick', 'brown', 'foxes', 'are', 'jumping', 'over', 'the', 'lazy', 'dogs', '.']
# Stemmed tokens: ['the', 'quick', 'brown', 'fox', 'are', 'jump', 'over', 'the', 'lazi', 'dog', '.']

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer

# teks yang akan diproses
txt = 'The quick brown foxes are jumping over the lazy dogs.'

# tokenisasi teks
tokens = word_tokenize(txt)

# inisialisasi snowball stemmer untuk bhs inggris
showball_stemmer = SnowballStemmer('english')

# proses stemming
stemmed_words = [showball_stemmer.stem(word) for word in tokens]

# menampilkan hasil
print('Original tokens:', tokens)
print('Stemmed tokens:', stemmed_words)
# Out:
# Original tokens: ['The', 'quick', 'brown', 'foxes', 'are', 'jumping', 'over', 'the', 'lazy', 'dogs', '.']
# Stemmed tokens: ['the', 'quick', 'brown', 'fox', 'are', 'jump', 'over', 'the', 'lazi', 'dog', '.']

# %%
from nltk.stem import RegexpStemmer

# inisialisasi RegexpStemmer dengan pola untuk menghapus akhiran 'ing'
txt = RegexpStemmer('ing$')

# contoh kata yg akan di stem
words = ['running', 'jummping','singing','played','eating']
# buat var dengan tipe data list atau array untuk kumpulan data

stemmed_words = [txt.stem(word)for word in words]

print('Original words:', words)
print('Stemmed words (using RegexpStemmer):', stemmed_words)
# Out:
# Original words: ['running', 'jummping', 'singing', 'played', 'eating']
# Stemmed words (using RegexpStemmer): ['runn', 'jummp', 'sing', 'played', 'eat']

# %% [markdown]
# ## Lemmattizing

# %% [markdown]
# Lemmatizing dengan NLTK

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
txt = 'the quick brown foxes are jumping over the lazy dogs.'

tokens = word_tokenize(txt)

lemmatizer = WordNetLemmatizer()

lemmatizer_word = [lemmatizer.lemmatize(word) for word in tokens]

print('Original text :', tokens)
print('Lemmatized text :', lemmatizer_word)
# Out:
# Original text : ['the', 'quick', 'brown', 'foxes', 'are', 'jumping', 'over', 'the', 'lazy', 'dogs', '.']
# Lemmatized text : ['the', 'quick', 'brown', 'fox', 'are', 'jumping', 'over', 'the', 'lazy', 'dog', '.']

# %%
# !pip install nlp-id
# Out:
# Collecting nlp-id
#   Downloading nlp_id-0.1.19.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: huggingface-hub==0.31.1 in /usr/local/lib/python3.11/dist-packages (from nlp-id) (0.31.1)
# Requirement already satisfied: nltk==3.9.1 in /usr/local/lib/python3.11/dist-packages (from nlp-id) (3.9.1)
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.11/dist-packages (from nlp-id) (2.0.2)
# Requirement already satisfied: scikit-learn==1.6.1 in /usr/local/lib/python3.11/dist-packages (from nlp-id) (1.6.1)
# Collecting scipy==1.15.3 (from nlp-id)
#   Downloading scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.3 MB/s eta 0:00:00
# Collecting wget==3.2 (from nlp-id)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk==3.9.1->nlp-id) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk==3.9.1->nlp-id) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk==3.9.1->nlp-id) (2024.11.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1->nlp-id) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.31.1->nlp-id) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.31.1->nlp-id) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.31.1->nlp-id) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.31.1->nlp-id) (2025.4.26)
# Downloading nlp_id-0.1.19.0-py3-none-any.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 50.1 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 27.2 MB/s eta 0:00:00
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=1e8ae1c01334d84bf37a1eb2a26a445fdffb58f42a225b5a8a6021c46e8e07ac
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# Installing collected packages: wget, scipy, nlp-id
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
# Successfully installed nlp-id-0.1.19.0 scipy-1.15.3 wget-3.2

# %%
import pandas as pd
import string
import re
import json
from nlp_id.lemmatizer import Lemmatizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
lemmatizer = Lemmatizer()

# %%
lemmatizer.lemmatize('Pemrosesan bahasa alami adalah hal yang peting untuk dipelajari, berlari merupakan proses mencapai tujuan dengan cepat')
# Out:
# 'proses bahasa alami adalah hal yang peting untuk ajar lari rupa proses capai tuju dengan cepat'

# %% [markdown]
# ## Normalisasi

# %%
txt = 'U tkp dmn ?'
slang_dict = {'U': 'Anda', 'tkp' : 'tempat', 'dmn' : 'dimana'}

normalized_txt = ' '.join((slang_dict.get(word, word)for word in txt.split()))
print(normalized_txt)
# Out:
# Anda tempat dimana ?

# %% [markdown]
# ## Spell Checker

# %% [markdown]
# Spell checker dengan TextBlob

# %%
from textblob import TextBlob

txt = 'Ths is a splellng error.'
blob = TextBlob(txt)
normalized_txt = str(blob.correct())
print(normalized_txt)
# Out:
# The is a spelling error.

# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.2-py3-none-any.whl.metadata (9.4 kB)
# Downloading pyspellchecker-0.8.2-py3-none-any.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 42.3 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.2

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

txt = 'this is an exampel of a spell cheker.'

words = text.split()

corrected_words = [spell.candidates(word) for word in words]
corrected_txt = ' '.join([spell.candidates(word).pop() if spell.unknown([word]) else word for in words])

print('Original text:', txt)
print('Corrected text:', corrected_txt)
# Out:
#   File "<ipython-input-44-fc03dced2729>", line 10
#     corrected_txt = ' '.join([spell.candidates(word).pop() if spell.unknown([word]) else word for in words])
#                                                                                                   ^
# SyntaxError: invalid syntax

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

txt = 'this is an exampel of a spell cheker.'

words = txt.split() # Changed text to txt to use the defined variable

corrected_words = [spell.candidates(word) for word in words]
# Corrected the list comprehension syntax
corrected_txt = ' '.join([spell.candidates(word).pop() if spell.unknown([word]) else word for word in words])

print('Original text:', txt)
print('Corrected text:', corrected_txt)
# Out:
# Original text: this is an exampel of a spell cheker.
# Corrected text: this is an example of a spell cheers

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

txt = 'ths is an exmpl of a spell chker.'

words = txt.split() # Changed text to txt to use the defined variable

corrected_words = [spell.candidates(word) for word in words]
# Corrected the list comprehension syntax
corrected_txt = ' '.join([spell.candidates(word).pop() if spell.unknown([word]) else word for word in words])

print('Original text:', txt)
print('Corrected text:', corrected_txt)
# Out:
# Original text: ths is an exmpl of a spell chker.
# Corrected text: this is an excel of a spell cheers

# %% [markdown]
# ## Gabungan

# %% [markdown]
# Stem dan stopword dengan NTLK english

# %%
import nltk
nltk.download('punkt_tab')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

txt = 'The quick brown foxes are jumping over the lazy dogs.'

tokens = word_tokenize(txt)

stop_words = set(stopwords.words('english'))

filtered_words = [word for word in tokens if word.lower() not in stop_words]

porter_stemmer = PorterStemmer()

stemmed_words = [porter_stemmer.stem(word) for word in filtered_words]

print('Original tokens:', tokens)
print('Filtered words:', filtered_words)
print('Stemed tokens:', stemmed_words)
# Out:
# Original tokens: ['The', 'quick', 'brown', 'foxes', 'are', 'jumping', 'over', 'the', 'lazy', 'dogs', '.']
# Filtered words: ['quick', 'brown', 'foxes', 'jumping', 'lazy', 'dogs', '.']
# Stemed tokens: ['quick', 'brown', 'fox', 'jump', 'lazi', 'dog', '.']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.11/dist-packages (1.0.1)

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

stopword_factory = StopWordRemoverFactory()
stopword_remover = stopword_factory.create_stop_word_remover()

stemmer_factory = StemmerFactory()
stemmer = stemmer_factory.create_stemmer()

txt = 'Pemrosesan bhs alami adalah hal yg penting untuk dipelajari'

cleaned_txt = stopword_remover.remove(txt)

stemmed_txt = stemmer.stem(cleaned_txt)

print('Original text:', txt)
print('Text after stopword removal:', cleaned_txt)
print('Stemmed text:', stemmed_txt)
# Out:
# Original text: Pemrosesan bhs alami adalah hal yg penting untuk dipelajari
# Text after stopword removal: Pemrosesan bhs alami hal yg penting dipelajari
# Stemmed text: pemrosesan bhs alami hal yg penting ajar

# %%
# !pip install nlp-id
# Out:
# Collecting nlp-id
#   Downloading nlp_id-0.1.19.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: huggingface-hub==0.31.1 in /usr/local/lib/python3.11/dist-packages (from nlp-id) (0.31.1)
# Requirement already satisfied: nltk==3.9.1 in /usr/local/lib/python3.11/dist-packages (from nlp-id) (3.9.1)
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.11/dist-packages (from nlp-id) (2.0.2)
# Requirement already satisfied: scikit-learn==1.6.1 in /usr/local/lib/python3.11/dist-packages (from nlp-id) (1.6.1)
# Requirement already satisfied: scipy==1.15.3 in /usr/local/lib/python3.11/dist-packages (from nlp-id) (1.15.3)
# Collecting wget==3.2 (from nlp-id)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.31.1->nlp-id) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk==3.9.1->nlp-id) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk==3.9.1->nlp-id) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk==3.9.1->nlp-id) (2024.11.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1->nlp-id) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.31.1->nlp-id) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.31.1->nlp-id) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.31.1->nlp-id) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub==0.31.1->nlp-id) (2025.4.26)
# Downloading nlp_id-0.1.19.0-py3-none-any.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 71.5 MB/s eta 0:00:00
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=41f31259efbdd0dd42c567cdb7561a2f2979819f451a408932bc44aa1b0b180b
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# Installing collected packages: wget, nlp-id
# Successfully installed nlp-id-0.1.19.0 wget-3.2

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from nlp_id.lemmatizer import Lemmatizer

# membuat object stopword remover
stopword_factory = StopWordRemoverFactory()
stopword_remover = stopword_factory.create_stop_word_remover()

# membuat objec lemmatizer
lemmatizer = Lemmatizer()

# text asli
txt = 'Pemrosesan bhs alami adalah hal yg penting untuk dipelajari'

# mengahapus stopword dari teks
cleaned_txt = stopword_remover.remove(txt)

# melakukan lemmatization pada teks
lemmatized_txt = lemmatizer.lemmatize(cleaned_txt)

print('Original txt:', txt)
print('Text after stopword removal:', cleaned_txt)
print('Lemmatized text:', lemmatized_txt)
# Out:
# Original txt: Pemrosesan bhs alami adalah hal yg penting untuk dipelajari
# Text after stopword removal: Pemrosesan bhs alami hal yg penting dipelajari
# Lemmatized text: proses bhs alami hal yg penting ajar

# %% [markdown]
# # Text to Feature Part 1

# %% [markdown]
# ## One Hot Encoding

# %%
import pandas as pd

Text = 'I am learning NLP'

pd.get_dummies(Text.split())
# Out:
#        I    NLP     am  learning
# 0   True  False  False     False
# 1  False  False   True     False
# 2  False  False  False      True
# 3  False   True  False     False

# %%
import pandas as pd

text = 'i am learning NLP learning'

# merubah tipe data string atau boolean menjadi int
dt = pd.get_dummies(text.split())
dt = dt.astype(int)
dt
# Out:
#    NLP  am  i  learning
# 0    0   0  1         0
# 1    0   1  0         0
# 2    0   0  0         1
# 3    1   0  0         0
# 4    0   0  0         1

# %% [markdown]
# ## Hash Vectorizer

# %%
from sklearn.feature_extraction.text import HashingVectorizer

text_data = ['i am learning NLP', 'NLP IS FUN']

vectorizer = HashingVectorizer(n_features=10)

x = vectorizer.transform(text_data)

print('Hashing Vectorizer:\n', x.toarray())
# Out:
# Hashing Vectorizer:
#  [[ 0.          0.          0.          0.         -0.57735027  0.57735027
#    0.          0.57735027  0.          0.        ]
#  [ 0.          0.          0.          0.          0.         -0.4472136
#    0.          0.89442719  0.          0.        ]]

# %% [markdown]
# ## N-Gram

# %%
from nltk import ngrams

def generate_ngrams(text, n):
    tokens = text.split()
    return list(ngrams(tokens, n))

text = 'Saya suka belajar ngoding'
n = 1
uni_grams = generate_ngrams(text,n)
print(uni_grams)
# Out:
# [('Saya',), ('suka',), ('belajar',), ('ngoding',)]

# %%
from nltk import ngrams

def generate_ngrams(text, n):
    tokens = text.split()
    return list(ngrams(tokens, n))

text = 'Saya suka belajar ngoding'
n = 2
uni_grams = generate_ngrams(text,n)
print(uni_grams)
# Out:
# [('Saya', 'suka'), ('suka', 'belajar'), ('belajar', 'ngoding')]

# %%
from nltk import ngrams

def generate_ngrams(text, n):
    tokens = text.split()
    return list(ngrams(tokens, n))

text = 'Saya suka belajar ngoding'
n = 3
uni_grams = generate_ngrams(text,n)
print(uni_grams)
# Out:
# [('Saya', 'suka', 'belajar'), ('suka', 'belajar', 'ngoding')]

# %% [markdown]
# ## Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

text_data = ['hello world world','world is beautiful','hellow agian']

vectorizer = CountVectorizer()
X= vectorizer.fit_transform(text_data)

print(x.toarray())
# Out:
# [[ 0.          0.          0.          0.         -0.57735027  0.57735027
#    0.          0.57735027  0.          0.        ]
#  [ 0.          0.          0.          0.          0.         -0.4472136
#    0.          0.89442719  0.          0.        ]]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

text_data = {
    'text': [
        'This is the first document.',
        'This document is the second document.',
        'And this is the third one.',
        'Is this the first document?'
    ]
}

dt = pd.DataFrame(text_data)

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(dt['text'])
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

print('TF-IDF Matrix:')
tfidf_df
# Out:
# TF-IDF Matrix:
#         and  document     first        is       one    second       the  \
# 0  0.000000  0.469791  0.580286  0.384085  0.000000  0.000000  0.384085
# 1  0.000000  0.687624  0.000000  0.281089  0.000000  0.538648  0.281089
# 2  0.511849  0.000000  0.000000  0.267104  0.511849  0.000000  0.267104
# 3  0.000000  0.469791  0.580286  0.384085  0.000000  0.000000  0.384085
#
#       third      this
# 0  0.000000  0.384085
# 1  0.000000  0.281089
# 2  0.511849  0.267104
# 3  0.000000  0.384085

# %% [markdown]
# ## Cosine Similiarty

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

pertanyaan = [
    'Apa itu Natural Language Processing?',
    'Bagaimana cara kerja Machine Learning?',
    'Apa bedanya supervised dan unsupervised learning?',
    'Apa itu chatbot?',
    'Bagaimana cara kerja chatbot?',
    'Apa itu AI?'
]

jawaban = [
    'Natural Language Processing adalah cabang AI yg menangani pemrosesan bhs manusia',
    'Machine Learning bekerja dengan melatih model menggunakan data untuk membuat prediksi',
    'Supervised learning menggunakan label data, sedangkan unsupervised learning tidak',
    'Chatbot adalah progam komputer yg dirancangn berinteraksi dengan manusia',
    'AI adalah bidang yg menciptakan mesin cerdas'
]

# Preprocessing TF-IDF
vectorizer = TfidfVectorizer()

# Mentransformasikan pertnyaan menjadi vekctor TF-IDF
tfidf_matrix = vectorizer.fit_transform(pertanyaan)

# Fungsi untuk Chatbot menggunakan Cosine Similarity
def chatbot_response(input_user):
    # Mentransformasi input pengguna menjadi vektor TF-IDF
    input_tfidf = vectorizer.transform([input_user])

    # Menghitung kesamaan cosine antara input dan pertanyaan yg ada
    similarity_scores = cosine_similarity(input_tfidf, tfidf_matrix)

    # Mendapatkan indeks pertanyaan yang paling mirip
    index_most_similar = np.argmax(similarity_scores)

    # Mengembalikan jawaban yg sesuai
    return jawaban[index_most_similar]

# Simulasi Chatbot
while True:
  input_user = input('User:')

  if input_user.lower() == 'exit':
      print('Chatbot: Terimakasih dan Sampai Jumpa')
      break

  response = chatbot_response(input_user)
  print('Chatbot:', response)
# Out:
# User:AI
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-e70df5e24f6f> in <cell line: 0>()
#      48       break
#      49
# ---> 50   response = chatbot_response(input_user)
#      51   print('Chatbot:', response)
#
# <ipython-input-1-e70df5e24f6f> in chatbot_response(input_user)
#      38
#      39     # Mengembalikan jawaban yg sesuai
# ---> 40     return jawaban[index_most_similar]
#      41
#      42 # Simulasi Chatbot
#
# IndexError: list index out of range

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

pertanyaan = [
    'Apa itu Natural Language Processing?',
    'Bagaimana cara kerja Machine Learning?',
    'Apa bedanya supervised dan unsupervised learning?',
    'Apa itu chatbot?',
    'Bagaimana cara kerja chatbot?',
    'Apa itu AI?' # This is the 6th question, index 5
]

jawaban = [
    'Natural Language Processing adalah cabang AI yg menangani pemrosesan bhs manusia', # Answer for index 0
    'Machine Learning bekerja dengan melatih model menggunakan data untuk membuat prediksi', # Answer for index 1
    'Supervised learning menggunakan label data, sedangkan unsupervised learning tidak', # Answer for index 2
    'Chatbot adalah progam komputer yg dirancangn berinteraksi dengan manusia', # Answer for index 3
    'AI adalah bidang yg menciptakan mesin cerdas', # Answer for index 4
    'AI atau Kecerdasan Buatan adalah bidang ilmu komputer yang berfokus pada pembuatan mesin yang dapat berpikir dan belajar seperti manusia.' # Added answer for index 5
]

# Preprocessing TF-IDF
vectorizer = TfidfVectorizer()

# Mentransformasikan pertnyaan menjadi vekctor TF-IDF
tfidf_matrix = vectorizer.fit_transform(pertanyaan)

# Fungsi untuk Chatbot menggunakan Cosine Similarity
def chatbot_response(input_user):
    # Mentransformasi input pengguna menjadi vektor TF-IDF
    input_tfidf = vectorizer.transform([input_user])

    # Menghitung kesamaan cosine antara input dan pertanyaan yg ada
    similarity_scores = cosine_similarity(input_tfidf, tfidf_matrix)

    # Mendapatkan indeks pertanyaan yang paling mirip
    index_most_similar = np.argmax(similarity_scores)

    # Mengembalikan jawaban yg sesuai
    return jawaban[index_most_similar]

# Simulasi Chatbot
while True:
  input_user = input('User:')

  if input_user.lower() == 'exit':
      print('Chatbot: Terimakasih dan Sampai Jumpa')
      break

  response = chatbot_response(input_user)
  print('Chatbot:', response)
# Out:
# User:AI
# Chatbot: AI atau Kecerdasan Buatan adalah bidang ilmu komputer yang berfokus pada pembuatan mesin yang dapat berpikir dan belajar seperti manusia.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-16573266a0b5> in <cell line: 0>()
#      43 # Simulasi Chatbot
#      44 while True:
# ---> 45   input_user = input('User:')
#      46
#      47   if input_user.lower() == 'exit':
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np


pertanyaan = [
    'Apa itu Natural Language Processing?',
    'Bagaimana cara kerja Machine Learning?',
    'Apa bedanya supervised dan unsupervised learning?',
    'Apa itu chatbot?',
    'Bagaimana cara kerja chatbot?',
    'Apa itu AI?' # This is the 6th question, index 5
]

# %% [markdown]
# ## Glove

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# ## Decision Tree

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
komentar = pd.read_csv("/content/drive/MyDrive/lagiviraldicnn.csv")
komentar
# Out:
#     conversation_id_str                      created_at  favorite_count  \
# 0   1928998276650467623  Sun Jun 01 15:54:35 +0000 2025               0
# 1   1928998276650467623  Sun Jun 01 12:20:41 +0000 2025               0
# 2   1928998276650467623  Sun Jun 01 03:07:39 +0000 2025              14
# 3   1928998276650467623  Sun Jun 01 02:53:11 +0000 2025               0
# 4   1928998276650467623  Sun Jun 01 16:11:46 +0000 2025               0
# 5   1928998276650467623  Sun Jun 01 03:01:52 +0000 2025              47
# 6   1928998276650467623  Sun Jun 01 17:08:56 +0000 2025               0
# 7   1928998276650467623  Sun Jun 01 03:55:38 +0000 2025               0
# 8   1928998276650467623  Sun Jun 01 15:39:36 +0000 2025               0
# 9   1928998276650467623  Sun Jun 01 05:12:14 +0000 2025               5
# 10  1928998276650467623  Sun Jun 01 05:07:04 +0000 2025               1
# 11  1928998276650467623  Sun Jun 01 15:10:11 +0000 2025               0
# 12  1928998276650467623  Sun Jun 01 05:24:57 +0000 2025               2
# 13  1928998276650467623  Sun Jun 01 15:40:03 +0000 2025               0
# 14  1928998276650467623  Sun Jun 01 12:55:16 +0000 2025               0
# 15  1928998276650467623  Sun Jun 01 07:03:57 +0000 2025               0
# 16  1928998276650467623  Sun Jun 01 09:43:43 +0000 2025               3
# 17  1928998276650467623  Sun Jun 01 02:50:57 +0000 2025               5
# 18  1928998276650467623  Sun Jun 01 13:15:09 +0000 2025               0
# 19  1928998276650467623  Sun Jun 01 09:34:18 +0000 2025               0
# 20  1928998276650467623  Sun Jun 01 02:32:21 +0000 2025              11
# 21  1928998276650467623  Sun Jun 01 12:07:09 +0000 2025               0
# 22  1927057708869464321  Mon May 26 17:42:15 +0000 2025              11
# 23  1928998276650467623  Sun Jun 01 08:01:20 +0000 2025               2
# 24  1928998276650467623  Sun Jun 01 03:07:03 +0000 2025              17
# 25  1928998276650467623  Sun Jun 01 16:30:03 +0000 2025               0
# 26  1928998276650467623  Sun Jun 01 07:19:46 +0000 2025               0
# 27  1928998276650467623  Sun Jun 01 04:16:50 +0000 2025              25
# 28  1928998276650467623  Sun Jun 01 13:12:16 +0000 2025               0
# 29  1928998276650467623  Sun Jun 01 03:04:39 +0000 2025               3
# 30  1928998276650467623  Sun Jun 01 12:12:26 +0000 2025               0
# 31  1928998276650467623  Sun Jun 01 03:05:52 +0000 2025               0
# 32  1928998276650467623  Sun Jun 01 12:25:19 +0000 2025               0
# 33  1928998276650467623  Sun Jun 01 03:03:43 +0000 2025               0
# 34  1928998276650467623  Sun Jun 01 08:04:32 +0000 2025               0
# 35  1928998276650467623  Sun Jun 01 16:03:57 +0000 2025               1
# 36  1928998276650467623  Sun Jun 01 07:08:02 +0000 2025               0
# 37  1928998276650467623  Sun Jun 01 05:10:26 +0000 2025               0
# 38  1928998276650467623  Sun Jun 01 05:03:53 +0000 2025               1
# 39  1928998276650467623  Sun Jun 01 08:36:17 +0000 2025               1
# 40  1928998276650467623  Sun Jun 01 03:59:17 +0000 2025               0
# 41  1928998276650467623  Sun Jun 01 06:31:22 +0000 2025               0
# 42  1928998276650467623  Sun Jun 01 05:13:23 +0000 2025               0
# 43  1928998276650467623  Sun Jun 01 10:33:49 +0000 2025               0
# 44  1928998276650467623  Sun Jun 01 12:23:00 +0000 2025               0
# 45  1928998276650467623  Sun Jun 01 12:34:12 +0000 2025               0
# 46  1928998276650467623  Sun Jun 01 15:27:49 +0000 2025               0
# 47  1928998276650467623  Sun Jun 01 07:14:45 +0000 2025               0
# 48  1928998276650467623  Sun Jun 01 03:19:46 +0000 2025               0
# 49  1928998276650467623  Sun Jun 01 05:16:56 +0000 2025               0
# 50  1928998276650467623  Sun Jun 01 12:24:40 +0000 2025               0
#
#                                             full_text               id_str  \
# 0   @CNNIndonesia Kan memang laku jelantah bekas i...  1929204939244376348
# 1   @CNNIndonesia Kebun kelapa sawit jutaan hektar...  1929151109412569319
# 2   @CNNIndonesia Pak presiden @prabowo bang @bang...  1929011933979594869
# 3                @CNNIndonesia Ngawur terus nih orang  1929008295013965980
# 4                         @CNNIndonesia Makin sinting  1929209264348037372
# 5   @CNNIndonesia Minyak jelantah itu kalau diusap...  1929010478564475354
# 6          @CNNIndonesia PENCAPAIAN LUAR BIASA TUAN!!  1929223649904476368
# 7   @CNNIndonesia Ada ada aja ucapan yg nyeleneh d...  1929024010538664112
# 8   @CNNIndonesia suruh nya olesin minyak jelantah...  1929201168573440235
# 9   @CNNIndonesia Orang ini mulutnya keterlaluan k...  1929043287471477109
# 10  @CNNIndonesia Lu suruh gue positif ama negara ...  1929041989426655333
# 11  @CNNIndonesia Anak dan keluarganya udah target...  1929193768986505523
# 12  @CNNIndonesia Ini yg ada dan di lakukan orang ...  1929046490221261215
# 13     @CNNIndonesia Kumbang larva nongol mulu sumpah  1929201282150973631
# 14  @CNNIndonesia Mengapa diksi bos BGN cenderung ...  1929159815999152392
# 15  @CNNIndonesia Dijual ke mana? Ke warung makan?...  1929071402059026604
# 16  @CNNIndonesia Bisa buat ngolesi kepala botak j...  1929111609743741171
# 17  @CNNIndonesia Halu-nya super kelewatan ini. Te...  1929007734126481599
# 18  @CNNIndonesia Wait wong Iki kok iso nemen ngen...  1929164819040518418
# 19            @CNNIndonesia Makin ngaco aja ini dunia  1929109238380478631
# 20  @CNNIndonesia Pas dibaca isi beritanya semuany...  1929003051546808480
# 21  @CNNIndonesia Program penuh masalah kok dibang...  1929147707131896216
# 22  a room with 3 mirrors [m_01] A room with three...  1927057708869464321
# 23  @CNNIndonesia isi otaknya cuma cuan.. mending ...  1929085844205273328
# 24  @CNNIndonesia Pedagang disuruh ngurus negeri.....  1929011784838439337
# 25                                     @CNNIndonesia   1929213865105281131
# 26                                 @CNNIndonesia ‍️‍️  1929075385162945002
# 27  @CNNIndonesia Bapak ini kayak Iklan rokok. Mak...  1929029348373266799
# 28  @CNNIndonesia pemerintah bs gasi stop ngasi st...  1929164094482874604
# 29  @CNNIndonesia Sebaiknya kalau pengetahuan tent...  1929011180816724280
# 30  @CNNIndonesia Kalau dijual mahal udah banyak y...  1929149034423287926
# 31     @CNNIndonesia Sudahlah pak hentikan ngibul nya  1929011485889503489
# 32  @CNNIndonesia Bisa dijadikan bio solar B40 itu...  1929152275622084947
# 33                        @CNNIndonesia Bapak sehat ?  1929010944140542052
# 34                   @CNNIndonesia Udah yuk udahan?..  1929086647620010414
# 35  @CNNIndonesia damn keren bgt statement tolol s...  1929207300041871433
# 36   @CNNIndonesia Orang2 titipan jokowi rata2 bodoh.  1929072428413542471
# 37  @CNNIndonesia Kebanyakan pegang anggaran jd bi...  1929042835350667639
# 38               @CNNIndonesia boleh hina dia ga sih?  1929041187442495550
# 39  @CNNIndonesia Muka lu sini aja gua jejelin min...  1929094638297563642
# 40                        @CNNIndonesia Make ni orang  1929024928969371825
# 41    @CNNIndonesia Minimal tumbuhin rambut lu tuh...  1929063203364798835
# 42                 @CNNIndonesia MBG Program SAMPAH‼️  1929043577104900199
# 43  @CNNIndonesia Kemarin sempat usul disuruh maka...  1929124216743330258
# 44  @CNNIndonesia TAI ( Terimakasih Atas Informasi...  1929151694396420578
# 45  @CNNIndonesia Mau dirubah jadi minyak urut dip...  1929154513039954138
# 46  @CNNIndonesia Ini rupanya spek ketua Wkwkwkwkwkwk  1929198204110663960
# 47             @CNNIndonesia Bacotan enggak berfaedah  1929074121725354121
# 48                        @CNNIndonesia Ni orang ya .  1929014986631721074
# 49  @CNNIndonesia Emank minyak jelantahnya ditamba...  1929044471448051881
# 50  @CNNIndonesia Pliss pejabat indonesia stop asb...  1929152111876431908
#
#                                           image_url in_reply_to_screen_name  \
# 0                                               NaN            CNNIndonesia
# 1                                               NaN            CNNIndonesia
# 2                                               NaN            CNNIndonesia
# 3                                               NaN            CNNIndonesia
# 4                                               NaN            CNNIndonesia
# 5                                               NaN            CNNIndonesia
# 6                                               NaN            CNNIndonesia
# 7                                               NaN            CNNIndonesia
# 8                                               NaN            CNNIndonesia
# 9                                               NaN            CNNIndonesia
# 10                                              NaN            CNNIndonesia
# 11                                              NaN            CNNIndonesia
# 12                                              NaN            CNNIndonesia
# 13                                              NaN            CNNIndonesia
# 14                                              NaN            CNNIndonesia
# 15                                              NaN            CNNIndonesia
# 16                                              NaN            CNNIndonesia
# 17                                              NaN            CNNIndonesia
# 18                                              NaN            CNNIndonesia
# 19                                              NaN            CNNIndonesia
# 20                                              NaN            CNNIndonesia
# 21                                              NaN            CNNIndonesia
# 22                                              NaN                     NaN
# 23                                              NaN            CNNIndonesia
# 24                                              NaN            CNNIndonesia
# 25                                              NaN            CNNIndonesia
# 26                                              NaN            CNNIndonesia
# 27  https://pbs.twimg.com/media/GsVJ9yfbcAAJ5AW.jpg            CNNIndonesia
# 28                                              NaN            CNNIndonesia
# 29                                              NaN            CNNIndonesia
# 30                                              NaN            CNNIndonesia
# 31                                              NaN            CNNIndonesia
# 32                                              NaN            CNNIndonesia
# 33                                              NaN            CNNIndonesia
# 34                                              NaN            CNNIndonesia
# 35                                              NaN            CNNIndonesia
# 36                                              NaN            CNNIndonesia
# 37                                              NaN            CNNIndonesia
# 38                                              NaN            CNNIndonesia
# 39                                              NaN            CNNIndonesia
# 40                                              NaN            CNNIndonesia
# 41                                              NaN            CNNIndonesia
# 42                                              NaN            CNNIndonesia
# 43                                              NaN            CNNIndonesia
# 44                                              NaN            CNNIndonesia
# 45                                              NaN            CNNIndonesia
# 46                                              NaN            CNNIndonesia
# 47                                              NaN            CNNIndonesia
# 48                                              NaN            CNNIndonesia
# 49                                              NaN            CNNIndonesia
# 50                                              NaN            CNNIndonesia
#
#    lang  location  quote_count  reply_count  retweet_count  \
# 0    in       NaN            0            0              0
# 1    in       NaN            0            0              0
# 2    in       NaN            0            1              0
# 3    in       NaN            0            0              0
# 4    en       NaN            0            0              0
# 5    in       NaN            0            0              0
# 6    in       NaN            0            0              0
# 7    in       NaN            0            0              0
# 8    in       NaN            0            0              0
# 9    in       NaN            0            0              0
# 10   in       NaN            0            0              0
# 11   in       NaN            0            1              0
# 12   in       NaN            0            0              0
# 13   in       NaN            0            0              0
# 14   in       NaN            0            0              0
# 15   in       NaN            0            0              0
# 16   in       NaN            0            0              0
# 17   in       NaN            0            0              0
# 18   in       NaN            0            0              0
# 19   in       NaN            0            0              0
# 20   in       NaN            0            0              0
# 21   in       NaN            0            0              0
# 22   en       NaN            0            0              0
# 23   in       NaN            0            0              0
# 24   in       NaN            0            0              0
# 25  qme       NaN            0            0              0
# 26  qme       NaN            0            0              0
# 27   in       NaN            0            0              0
# 28   in       NaN            0            0              0
# 29   in       NaN            0            0              0
# 30   in       NaN            0            0              0
# 31   in       NaN            0            0              0
# 32   in       NaN            0            0              0
# 33   in       NaN            0            0              0
# 34   in       NaN            0            0              0
# 35   in       NaN            0            0              0
# 36   in       NaN            0            0              0
# 37   in       NaN            0            0              0
# 38   in       NaN            0            0              0
# 39   in       NaN            0            0              0
# 40   in       NaN            0            0              0
# 41   in       NaN            0            0              0
# 42   in       NaN            0            0              0
# 43   in       NaN            0            0              0
# 44   in       NaN            0            0              0
# 45   in       NaN            0            0              0
# 46   in       NaN            0            0              0
# 47   in       NaN            0            0              0
# 48   in       NaN            0            0              0
# 49   in       NaN            0            0              0
# 50   in       NaN            0            0              0
#
#                                             tweet_url          user_id_str  \
# 0   https://x.com/undefined/status/192920493924437...  1850934287710994432
# 1   https://x.com/undefined/status/192915110941256...  1835668063133589504
# 2   https://x.com/undefined/status/192901193397959...  1752878735001616384
# 3   https://x.com/undefined/status/192900829501396...             39462502
# 4   https://x.com/undefined/status/192920926434803...  1611552756321652736
# 5   https://x.com/undefined/status/192901047856447...  1902701320467042305
# 6   https://x.com/undefined/status/192922364990447...            354437648
# 7   https://x.com/undefined/status/192902401053866...  1650125083183296515
# 8   https://x.com/undefined/status/192920116857344...            156292006
# 9   https://x.com/undefined/status/192904328747147...           3235224685
# 10  https://x.com/undefined/status/192904198942665...            271250554
# 11  https://x.com/undefined/status/192919376898650...  1120769537635274752
# 12  https://x.com/undefined/status/192904649022126...  1727684626112811008
# 13  https://x.com/undefined/status/192920128215097...            357546824
# 14  https://x.com/undefined/status/192915981599915...            138331907
# 15  https://x.com/undefined/status/192907140205902...  1219289758389551105
# 16  https://x.com/undefined/status/192911160974374...             36009942
# 17  https://x.com/undefined/status/192900773412648...  1791804792379224064
# 18  https://x.com/undefined/status/192916481904051...            704679138
# 19  https://x.com/undefined/status/192910923838047...            211808584
# 20  https://x.com/undefined/status/192900305154680...  1744702724258643968
# 21  https://x.com/undefined/status/192914770713189...  1747712983369908224
# 22  https://x.com/undefined/status/192705770886946...  1899360657637871616
# 23  https://x.com/undefined/status/192908584420527...  1513694552443727873
# 24  https://x.com/undefined/status/192901178483843...  1763795955911176192
# 25  https://x.com/undefined/status/192921386510528...  1837298144184320000
# 26  https://x.com/undefined/status/192907538516294...            374673740
# 27  https://x.com/undefined/status/192902934837326...  1807372522616479744
# 28  https://x.com/undefined/status/192916409448287...           4742264971
# 29  https://x.com/undefined/status/192901118081672...  1571715970716307456
# 30  https://x.com/undefined/status/192914903442328...             74195784
# 31  https://x.com/undefined/status/192901148588950...  1106170356795142144
# 32  https://x.com/undefined/status/192915227562208...  1668088452305530880
# 33  https://x.com/undefined/status/192901094414054...           2868812979
# 34  https://x.com/undefined/status/192908664762001...  1605291193935400961
# 35  https://x.com/undefined/status/192920730004187...           3886880420
# 36  https://x.com/undefined/status/192907242841354...  1858647906938744833
# 37  https://x.com/undefined/status/192904283535066...  1148928890980589568
# 38  https://x.com/undefined/status/192904118744249...  1603688779721895936
# 39  https://x.com/undefined/status/192909463829756...   957675083081826305
# 40  https://x.com/undefined/status/192902492896937...            185626334
# 41  https://x.com/undefined/status/192906320336479...           1141687363
# 42  https://x.com/undefined/status/192904357710490...  1505766476816740353
# 43  https://x.com/undefined/status/192912421674333...  1686747209474228225
# 44  https://x.com/undefined/status/192915169439642...   830031149510520833
# 45  https://x.com/undefined/status/192915451303995...  1558972946471067648
# 46  https://x.com/undefined/status/192919820411066...            378986327
# 47  https://x.com/undefined/status/192907412172535...  1593826699749494784
# 48  https://x.com/undefined/status/192901498663172...             76294661
# 49  https://x.com/undefined/status/192904447144805...            223709269
# 50  https://x.com/undefined/status/192915211187643...  1545965005949915136
#
#     username
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32       NaN
# 33       NaN
# 34       NaN
# 35       NaN
# 36       NaN
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41       NaN
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46       NaN
# 47       NaN
# 48       NaN
# 49       NaN
# 50       NaN

# %%
komentar = komentar[['full_text']]
komentar
# Out:
#                                             full_text
# 0   @CNNIndonesia Kan memang laku jelantah bekas i...
# 1   @CNNIndonesia Kebun kelapa sawit jutaan hektar...
# 2   @CNNIndonesia Pak presiden @prabowo bang @bang...
# 3                @CNNIndonesia Ngawur terus nih orang
# 4                         @CNNIndonesia Makin sinting
# 5   @CNNIndonesia Minyak jelantah itu kalau diusap...
# 6          @CNNIndonesia PENCAPAIAN LUAR BIASA TUAN!!
# 7   @CNNIndonesia Ada ada aja ucapan yg nyeleneh d...
# 8   @CNNIndonesia suruh nya olesin minyak jelantah...
# 9   @CNNIndonesia Orang ini mulutnya keterlaluan k...
# 10  @CNNIndonesia Lu suruh gue positif ama negara ...
# 11  @CNNIndonesia Anak dan keluarganya udah target...
# 12  @CNNIndonesia Ini yg ada dan di lakukan orang ...
# 13     @CNNIndonesia Kumbang larva nongol mulu sumpah
# 14  @CNNIndonesia Mengapa diksi bos BGN cenderung ...
# 15  @CNNIndonesia Dijual ke mana? Ke warung makan?...
# 16  @CNNIndonesia Bisa buat ngolesi kepala botak j...
# 17  @CNNIndonesia Halu-nya super kelewatan ini. Te...
# 18  @CNNIndonesia Wait wong Iki kok iso nemen ngen...
# 19            @CNNIndonesia Makin ngaco aja ini dunia
# 20  @CNNIndonesia Pas dibaca isi beritanya semuany...
# 21  @CNNIndonesia Program penuh masalah kok dibang...
# 22  a room with 3 mirrors [m_01] A room with three...
# 23  @CNNIndonesia isi otaknya cuma cuan.. mending ...
# 24  @CNNIndonesia Pedagang disuruh ngurus negeri.....
# 25                                     @CNNIndonesia
# 26                                 @CNNIndonesia ‍️‍️
# 27  @CNNIndonesia Bapak ini kayak Iklan rokok. Mak...
# 28  @CNNIndonesia pemerintah bs gasi stop ngasi st...
# 29  @CNNIndonesia Sebaiknya kalau pengetahuan tent...
# 30  @CNNIndonesia Kalau dijual mahal udah banyak y...
# 31     @CNNIndonesia Sudahlah pak hentikan ngibul nya
# 32  @CNNIndonesia Bisa dijadikan bio solar B40 itu...
# 33                        @CNNIndonesia Bapak sehat ?
# 34                   @CNNIndonesia Udah yuk udahan?..
# 35  @CNNIndonesia damn keren bgt statement tolol s...
# 36   @CNNIndonesia Orang2 titipan jokowi rata2 bodoh.
# 37  @CNNIndonesia Kebanyakan pegang anggaran jd bi...
# 38               @CNNIndonesia boleh hina dia ga sih?
# 39  @CNNIndonesia Muka lu sini aja gua jejelin min...
# 40                        @CNNIndonesia Make ni orang
# 41    @CNNIndonesia Minimal tumbuhin rambut lu tuh...
# 42                 @CNNIndonesia MBG Program SAMPAH‼️
# 43  @CNNIndonesia Kemarin sempat usul disuruh maka...
# 44  @CNNIndonesia TAI ( Terimakasih Atas Informasi...
# 45  @CNNIndonesia Mau dirubah jadi minyak urut dip...
# 46  @CNNIndonesia Ini rupanya spek ketua Wkwkwkwkwkwk
# 47             @CNNIndonesia Bacotan enggak berfaedah
# 48                        @CNNIndonesia Ni orang ya .
# 49  @CNNIndonesia Emank minyak jelantahnya ditamba...
# 50  @CNNIndonesia Pliss pejabat indonesia stop asb...

# %%
unique_categories = komentar['full_text'].unique()
print('Unique value in "full_text", column:',unique_categories)
# Out:
# Unique value in "full_text", column: ['@CNNIndonesia Kan memang laku jelantah bekas itu jadi gak salah memang ketua BGN statemennya sih dah pak gas aja Lanjutkan MBG dgn sistem.dan sop semakin baik'
#  '@CNNIndonesia Kebun kelapa sawit jutaan hektar dan terluas di dunia nggak kedengaran hasilnya untuk negara tau-tau ngomong minyak jelantahnya sisa sampah MBG bernilai jual tinggi Agak laen memang otak pejabat2 Konoha'
#  '@CNNIndonesia Pak presiden @prabowo bang @bang_dasco bang @Dahnilanzar @Gerindra tolong di resuffle aja pusing liatnya klw dia udah ngomong bawaanya ngeselin kenapa ya?'
#  '@CNNIndonesia Ngawur terus nih orang' '@CNNIndonesia Makin sinting'
#  '@CNNIndonesia Minyak jelantah itu kalau diusap ke kepala bapak bisa numbuhin rambut lho pak cepet hasilnya... coba aja'
#  '@CNNIndonesia PENCAPAIAN LUAR BIASA TUAN!!'
#  '@CNNIndonesia Ada ada aja ucapan yg nyeleneh dari pejabat konoha'
#  '@CNNIndonesia suruh nya olesin minyak jelantah di olesin di kepala nya biar + mengkilat botak nye'
#  '@CNNIndonesia Orang ini mulutnya keterlaluan kenapa gak coba ditertibkan ya? @prabowo @Gerindra @setkabgoid @KemensetnegRI'
#  '@CNNIndonesia Lu suruh gue positif ama negara ini? Yang ada kesehatan gue memburuk gegara baca berita negara ini doang.'
#  '@CNNIndonesia Anak dan keluarganya udah target. Walaupun mereka harus diam2. Bro mereka berpiker aman'
#  '@CNNIndonesia Ini yg ada dan di lakukan orang ada lho yg punya program 3 botol jelantah di tukar 1 botol dr mereka di daur ulang lagi mungkin jika selama ini blm ada yg tahu atau pura-pura g tahu makanya hati-hati.'
#  '@CNNIndonesia Kumbang larva nongol mulu sumpah'
#  '@CNNIndonesia Mengapa diksi bos BGN cenderung provokatif?'
#  '@CNNIndonesia Dijual ke mana? Ke warung makan? Pemerentah kok tiap jawaban dan kebijakannya kek forum bapak2 ngeriung di pos ronda yg lg becanda mulu'
#  '@CNNIndonesia Bisa buat ngolesi kepala botak juga ya..'
#  '@CNNIndonesia Halu-nya super kelewatan ini. Ternyata Oknum pejabat yg satu ini gak kalah ngawurnya dg Mulyono dn Paman Gembul. Cocok emang Oknum model gini jadi Pejabat di Rezim Omon-Omon/ Kibal-Kibul ala Si Mulyono dan Paman Gembul. '
#  '@CNNIndonesia Wait wong Iki kok iso nemen ngene.. Kejiwaan tingkat berapa sih sebenarnya...???'
#  '@CNNIndonesia Makin ngaco aja ini dunia'
#  '@CNNIndonesia Pas dibaca isi beritanya semuanya cuma kumur kumur doang '
#  '@CNNIndonesia Program penuh masalah kok dibangga-banggakan '
#  'a room with 3 mirrors [m_01] A room with three mirrors Two that reflect And one that reminds you Of your own transparency https://t.co/dMRCuM6KQY #X3NDRAKAN @SunoMusic #aroomwith3mirrors #griefwave'
#  '@CNNIndonesia isi otaknya cuma cuan.. mending main golf aja pak daripada komentar yg aneh²'
#  '@CNNIndonesia Pedagang disuruh ngurus negeri... tolok ukur keberhasilannya dan positif goalnya agak lain emang'
#  '@CNNIndonesia ' '@CNNIndonesia \u200d️\u200d️'
#  '@CNNIndonesia Bapak ini kayak Iklan rokok. Makin Kesini Makin Kesana . Fokus aja ke menu biar anak yang makan ga keracunan. https://t.co/UXzaYseUpS'
#  '@CNNIndonesia pemerintah bs gasi stop ngasi statement asbun'
#  '@CNNIndonesia Sebaiknya kalau pengetahuan tentang jelantrah sebaiknya diam ! Diam !!!!!!'
#  '@CNNIndonesia Kalau dijual mahal udah banyak yang kaya raya blok.'
#  '@CNNIndonesia Sudahlah pak hentikan ngibul nya'
#  '@CNNIndonesia Bisa dijadikan bio solar B40 itu pak... '
#  '@CNNIndonesia Bapak sehat ?' '@CNNIndonesia Udah yuk udahan?..'
#  '@CNNIndonesia damn keren bgt statement tolol satu ini anjenggg'
#  '@CNNIndonesia Orang2 titipan jokowi rata2 bodoh.'
#  '@CNNIndonesia Kebanyakan pegang anggaran jd bingung mau ngomong apa'
#  '@CNNIndonesia boleh hina dia ga sih?'
#  '@CNNIndonesia Muka lu sini aja gua jejelin minyak jelantah botak!'
#  '@CNNIndonesia Make ni orang'
#  '@CNNIndonesia Minimal tumbuhin rambut lu tuh...'
#  '@CNNIndonesia MBG Program SAMPAH‼️'
#  '@CNNIndonesia Kemarin sempat usul disuruh makan Belalang..ini orang beneran sinting.'
#  '@CNNIndonesia TAI ( Terimakasih Atas Informasinya )'
#  '@CNNIndonesia Mau dirubah jadi minyak urut dipasarkan di IKN..'
#  '@CNNIndonesia Ini rupanya spek ketua Wkwkwkwkwkwk'
#  '@CNNIndonesia Bacotan enggak berfaedah' '@CNNIndonesia Ni orang ya .'
#  '@CNNIndonesia Emank minyak jelantahnya ditambah emas jd mahal. Bisa diketawai pengepul minyak.'
#  '@CNNIndonesia Pliss pejabat indonesia stop asbun bisa ga sih? Muak banget anj']

# %%
# Out:
# Unique value in "Sex", column: ['M' 'F']

# %%
import pandas as pd
import re

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = text.split()
    return tokens

komentar['processed_text']= komentar['created_at'].apply(preprocess_text)

# Access the columns using a list of column names
print(komentar[['created_at', 'processed_text']])
# Out:
#                         created_at processed_text
# 0   Sun Jun 01 15:54:35 +0000 2025     [sun, jun]
# 1   Sun Jun 01 12:20:41 +0000 2025     [sun, jun]
# 2   Sun Jun 01 03:07:39 +0000 2025     [sun, jun]
# 3   Sun Jun 01 02:53:11 +0000 2025     [sun, jun]
# 4   Sun Jun 01 16:11:46 +0000 2025     [sun, jun]
# 5   Sun Jun 01 03:01:52 +0000 2025     [sun, jun]
# 6   Sun Jun 01 17:08:56 +0000 2025     [sun, jun]
# 7   Sun Jun 01 03:55:38 +0000 2025     [sun, jun]
# 8   Sun Jun 01 15:39:36 +0000 2025     [sun, jun]
# 9   Sun Jun 01 05:12:14 +0000 2025     [sun, jun]
# 10  Sun Jun 01 05:07:04 +0000 2025     [sun, jun]
# 11  Sun Jun 01 15:10:11 +0000 2025     [sun, jun]
# 12  Sun Jun 01 05:24:57 +0000 2025     [sun, jun]
# 13  Sun Jun 01 15:40:03 +0000 2025     [sun, jun]
# 14  Sun Jun 01 12:55:16 +0000 2025     [sun, jun]
# 15  Sun Jun 01 07:03:57 +0000 2025     [sun, jun]
# 16  Sun Jun 01 09:43:43 +0000 2025     [sun, jun]
# 17  Sun Jun 01 02:50:57 +0000 2025     [sun, jun]
# 18  Sun Jun 01 13:15:09 +0000 2025     [sun, jun]
# 19  Sun Jun 01 09:34:18 +0000 2025     [sun, jun]
# 20  Sun Jun 01 02:32:21 +0000 2025     [sun, jun]
# 21  Sun Jun 01 12:07:09 +0000 2025     [sun, jun]
# 22  Mon May 26 17:42:15 +0000 2025     [mon, may]
# 23  Sun Jun 01 08:01:20 +0000 2025     [sun, jun]
# 24  Sun Jun 01 03:07:03 +0000 2025     [sun, jun]
# 25  Sun Jun 01 16:30:03 +0000 2025     [sun, jun]
# 26  Sun Jun 01 07:19:46 +0000 2025     [sun, jun]
# 27  Sun Jun 01 04:16:50 +0000 2025     [sun, jun]
# 28  Sun Jun 01 13:12:16 +0000 2025     [sun, jun]
# 29  Sun Jun 01 03:04:39 +0000 2025     [sun, jun]
# 30  Sun Jun 01 12:12:26 +0000 2025     [sun, jun]
# 31  Sun Jun 01 03:05:52 +0000 2025     [sun, jun]
# 32  Sun Jun 01 12:25:19 +0000 2025     [sun, jun]
# 33  Sun Jun 01 03:03:43 +0000 2025     [sun, jun]
# 34  Sun Jun 01 08:04:32 +0000 2025     [sun, jun]
# 35  Sun Jun 01 16:03:57 +0000 2025     [sun, jun]
# 36  Sun Jun 01 07:08:02 +0000 2025     [sun, jun]
# 37  Sun Jun 01 05:10:26 +0000 2025     [sun, jun]
# 38  Sun Jun 01 05:03:53 +0000 2025     [sun, jun]
# 39  Sun Jun 01 08:36:17 +0000 2025     [sun, jun]
# 40  Sun Jun 01 03:59:17 +0000 2025     [sun, jun]
# 41  Sun Jun 01 06:31:22 +0000 2025     [sun, jun]
# 42  Sun Jun 01 05:13:23 +0000 2025     [sun, jun]
# 43  Sun Jun 01 10:33:49 +0000 2025     [sun, jun]
# 44  Sun Jun 01 12:23:00 +0000 2025     [sun, jun]
# 45  Sun Jun 01 12:34:12 +0000 2025     [sun, jun]
# 46  Sun Jun 01 15:27:49 +0000 2025     [sun, jun]
# 47  Sun Jun 01 07:14:45 +0000 2025     [sun, jun]
# 48  Sun Jun 01 03:19:46 +0000 2025     [sun, jun]
# 49  Sun Jun 01 05:16:56 +0000 2025     [sun, jun]
# 50  Sun Jun 01 12:24:40 +0000 2025     [sun, jun]

# %%
import pandas as pd
import re
from google.colab import drive

# Mount Google Drive if you haven't already
drive.mount('/content/drive')

# Load the original dataset
komentar = pd.read_csv("/content/drive/MyDrive/lagiviraldicnn.csv")

# Define the preprocessing function
def preprocess_text(text):
    # Ensure the input is treated as a string before applying lower()
    text = str(text).lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    tokens = text.split()
    return tokens

# Apply the preprocessing function to the 'full_text' column
komentar['processed_text'] = komentar['full_text'].apply(preprocess_text)

# Display the relevant columns to show the result
print(komentar[['full_text', 'processed_text']])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                             full_text  \
# 0   @CNNIndonesia Kan memang laku jelantah bekas i...
# 1   @CNNIndonesia Kebun kelapa sawit jutaan hektar...
# 2   @CNNIndonesia Pak presiden @prabowo bang @bang...
# 3                @CNNIndonesia Ngawur terus nih orang
# 4                         @CNNIndonesia Makin sinting
# 5   @CNNIndonesia Minyak jelantah itu kalau diusap...
# 6          @CNNIndonesia PENCAPAIAN LUAR BIASA TUAN!!
# 7   @CNNIndonesia Ada ada aja ucapan yg nyeleneh d...
# 8   @CNNIndonesia suruh nya olesin minyak jelantah...
# 9   @CNNIndonesia Orang ini mulutnya keterlaluan k...
# 10  @CNNIndonesia Lu suruh gue positif ama negara ...
# 11  @CNNIndonesia Anak dan keluarganya udah target...
# 12  @CNNIndonesia Ini yg ada dan di lakukan orang ...
# 13     @CNNIndonesia Kumbang larva nongol mulu sumpah
# 14  @CNNIndonesia Mengapa diksi bos BGN cenderung ...
# 15  @CNNIndonesia Dijual ke mana? Ke warung makan?...
# 16  @CNNIndonesia Bisa buat ngolesi kepala botak j...
# 17  @CNNIndonesia Halu-nya super kelewatan ini. Te...
# 18  @CNNIndonesia Wait wong Iki kok iso nemen ngen...
# 19            @CNNIndonesia Makin ngaco aja ini dunia
# 20  @CNNIndonesia Pas dibaca isi beritanya semuany...
# 21  @CNNIndonesia Program penuh masalah kok dibang...
# 22  a room with 3 mirrors [m_01] A room with three...
# 23  @CNNIndonesia isi otaknya cuma cuan.. mending ...
# 24  @CNNIndonesia Pedagang disuruh ngurus negeri.....
# 25                                     @CNNIndonesia
# 26                                 @CNNIndonesia ‍️‍️
# 27  @CNNIndonesia Bapak ini kayak Iklan rokok. Mak...
# 28  @CNNIndonesia pemerintah bs gasi stop ngasi st...
# 29  @CNNIndonesia Sebaiknya kalau pengetahuan tent...
# 30  @CNNIndonesia Kalau dijual mahal udah banyak y...
# 31     @CNNIndonesia Sudahlah pak hentikan ngibul nya
# 32  @CNNIndonesia Bisa dijadikan bio solar B40 itu...
# 33                        @CNNIndonesia Bapak sehat ?
# 34                   @CNNIndonesia Udah yuk udahan?..
# 35  @CNNIndonesia damn keren bgt statement tolol s...
# 36   @CNNIndonesia Orang2 titipan jokowi rata2 bodoh.
# 37  @CNNIndonesia Kebanyakan pegang anggaran jd bi...
# 38               @CNNIndonesia boleh hina dia ga sih?
# 39  @CNNIndonesia Muka lu sini aja gua jejelin min...
# 40                        @CNNIndonesia Make ni orang
# 41    @CNNIndonesia Minimal tumbuhin rambut lu tuh...
# 42                 @CNNIndonesia MBG Program SAMPAH‼️
# 43  @CNNIndonesia Kemarin sempat usul disuruh maka...
# 44  @CNNIndonesia TAI ( Terimakasih Atas Informasi...
# 45  @CNNIndonesia Mau dirubah jadi minyak urut dip...
# 46  @CNNIndonesia Ini rupanya spek ketua Wkwkwkwkwkwk
# 47             @CNNIndonesia Bacotan enggak berfaedah
# 48                        @CNNIndonesia Ni orang ya .
# 49  @CNNIndonesia Emank minyak jelantahnya ditamba...
# 50  @CNNIndonesia Pliss pejabat indonesia stop asb...
#
#                                        processed_text
# 0   [cnnindonesia, kan, memang, laku, jelantah, be...
# 1   [cnnindonesia, kebun, kelapa, sawit, jutaan, h...
# 2   [cnnindonesia, pak, presiden, prabowo, bang, b...
# 3           [cnnindonesia, ngawur, terus, nih, orang]
# 4                      [cnnindonesia, makin, sinting]
# 5   [cnnindonesia, minyak, jelantah, itu, kalau, d...
# 6       [cnnindonesia, pencapaian, luar, biasa, tuan]
# 7   [cnnindonesia, ada, ada, aja, ucapan, yg, nyel...
# 8   [cnnindonesia, suruh, nya, olesin, minyak, jel...
# 9   [cnnindonesia, orang, ini, mulutnya, keterlalu...
# 10  [cnnindonesia, lu, suruh, gue, positif, ama, n...
# 11  [cnnindonesia, anak, dan, keluarganya, udah, t...
# 12  [cnnindonesia, ini, yg, ada, dan, di, lakukan,...
# 13  [cnnindonesia, kumbang, larva, nongol, mulu, s...
# 14  [cnnindonesia, mengapa, diksi, bos, bgn, cende...
# 15  [cnnindonesia, dijual, ke, mana, ke, warung, m...
# 16  [cnnindonesia, bisa, buat, ngolesi, kepala, bo...
# 17  [cnnindonesia, halunya, super, kelewatan, ini,...
# 18  [cnnindonesia, wait, wong, iki, kok, iso, neme...
# 19      [cnnindonesia, makin, ngaco, aja, ini, dunia]
# 20  [cnnindonesia, pas, dibaca, isi, beritanya, se...
# 21  [cnnindonesia, program, penuh, masalah, kok, d...
# 22  [a, room, with, mirrors, m, a, room, with, thr...
# 23  [cnnindonesia, isi, otaknya, cuma, cuan, mendi...
# 24  [cnnindonesia, pedagang, disuruh, ngurus, nege...
# 25                                     [cnnindonesia]
# 26                                     [cnnindonesia]
# 27  [cnnindonesia, bapak, ini, kayak, iklan, rokok...
# 28  [cnnindonesia, pemerintah, bs, gasi, stop, nga...
# 29  [cnnindonesia, sebaiknya, kalau, pengetahuan, ...
# 30  [cnnindonesia, kalau, dijual, mahal, udah, ban...
# 31  [cnnindonesia, sudahlah, pak, hentikan, ngibul...
# 32  [cnnindonesia, bisa, dijadikan, bio, solar, b,...
# 33                       [cnnindonesia, bapak, sehat]
# 34                  [cnnindonesia, udah, yuk, udahan]
# 35  [cnnindonesia, damn, keren, bgt, statement, to...
# 36  [cnnindonesia, orang, titipan, jokowi, rata, b...
# 37  [cnnindonesia, kebanyakan, pegang, anggaran, j...
# 38          [cnnindonesia, boleh, hina, dia, ga, sih]
# 39  [cnnindonesia, muka, lu, sini, aja, gua, jejel...
# 40                    [cnnindonesia, make, ni, orang]
# 41  [cnnindonesia, minimal, tumbuhin, rambut, lu, ...
# 42               [cnnindonesia, mbg, program, sampah]
# 43  [cnnindonesia, kemarin, sempat, usul, disuruh,...
# 44  [cnnindonesia, tai, terimakasih, atas, informa...
# 45  [cnnindonesia, mau, dirubah, jadi, minyak, uru...
# 46  [cnnindonesia, ini, rupanya, spek, ketua, wkwk...
# 47         [cnnindonesia, bacotan, enggak, berfaedah]
# 48                      [cnnindonesia, ni, orang, ya]
# 49  [cnnindonesia, emank, minyak, jelantahnya, dit...
# 50  [cnnindonesia, pliss, pejabat, indonesia, stop...
